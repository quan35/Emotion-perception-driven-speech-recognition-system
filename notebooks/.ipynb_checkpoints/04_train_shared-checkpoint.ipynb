# %% [markdown]
# # 04 Whisper 共享编码器情感分类训练
# 复用 Whisper Encoder 作为特征提取器，冻结编码器参数，只训练分类头。

# %%
import os
IN_COLAB = 'COLAB_GPU' in os.environ or 'COLAB_RELEASE_TAG' in os.environ

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    PROJECT_ROOT = '/content/drive/MyDrive/identifier'
    os.chdir(PROJECT_ROOT)
    # !pip install -q openai-whisper noisereduce librosa soundfile pyyaml
else:
    # 自动查找项目根目录（兼容从任意目录启动 Jupyter）
    for _candidate in [os.path.abspath('..'), os.path.abspath('.'), os.path.expanduser('~/identifier')]:
        if os.path.isfile(os.path.join(_candidate, 'configs', 'config.yaml')):
            PROJECT_ROOT = _candidate
            break
    else:
        raise RuntimeError('找不到项目根目录，请确认 configs/config.yaml 存在')
    os.chdir(PROJECT_ROOT)

print(f'项目根目录: {os.getcwd()}')
# Out:
# 项目根目录: /root/Emotion-perception-driven-speech-recognition-system

# %%
import sys
import time
import copy
import glob
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, ConcatDataset, random_split
import whisper
import matplotlib.pyplot as plt

sys.path.insert(0, PROJECT_ROOT)
from utils.audio_utils import load_config, LABEL2ID, EMOTION_LABELS
from models.whisper_emotion import WhisperEmotionHead

cfg = load_config()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'设备: {device}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name()}')
# Out:
# libgomp: Invalid value for environment variable OMP_NUM_THREADS
# 设备: cuda
# GPU: NVIDIA GeForce RTX 4090

# %% [markdown]
# ## 1. 准备数据集

# %%
from torch.utils.data import random_split

from preprocessing.whisper_feature_cache import prepare_whisper_feature_dataset

"""论文演示目的：
- 使用 Whisper Encoder 作为冻结特征提取器（shared encoder），只训练轻量分类头
- 通过预先缓存 pooled encoder 特征（features_shared），提升训练速度

注意：features_shared 的缓存文件名只与 whisper_size 有关。
当新增数据集子集（如 emodb/iemocap）后，需要 overwrite=True 重新生成一次缓存，
否则会直接复用旧缓存，导致样本数不变。
"""

# 提取/缓存 Whisper encoder 池化特征（首次会计算并落盘，后续直接复用）
feature_bs = int(cfg.get("training", {}).get("whisper_feature_batch_size", 8))
feature_workers = int(cfg.get("training", {}).get("whisper_feature_num_workers", 0))
feature_prefetch = int(cfg.get("training", {}).get("whisper_feature_prefetch_factor", 2))

dataset, meta = prepare_whisper_feature_dataset(
    cfg=cfg,
    device=device,
    subsets=("ravdess", "casia", "tess", "esd", "emodb", "iemocap"),
    batch_size=feature_bs,
    feature_dtype="float16",
    overwrite=False,
    num_workers=feature_workers,
    prefetch_factor=feature_prefetch,
)
print(f"特征缓存元信息: {meta}")

# 划分 train/val/test
total = len(dataset)
train_n = int(total * cfg["training"]["train_ratio"])
val_n = int(total * cfg["training"]["val_ratio"])
test_n = total - train_n - val_n

gen = torch.Generator().manual_seed(cfg["training"]["seed"])
train_set, val_set, test_set = random_split(dataset, [train_n, val_n, test_n], generator=gen)

bs = int(cfg["training"]["batch_size"])
train_loader = DataLoader(train_set, batch_size=bs, shuffle=True, pin_memory=True)
val_loader = DataLoader(val_set, batch_size=bs, shuffle=False, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=bs, shuffle=False, pin_memory=True)

print(
    f"训练: {train_n}, 验证: {val_n}, 测试: {test_n}, "
    f"batch_size: {bs}, feature_batch_size: {feature_bs}, "
    f"feature_num_workers: {feature_workers}, feature_prefetch_factor: {feature_prefetch}"
)
# Out:
# 共 48187 个样本
#   已提取 1600/48187
#   已提取 3200/48187
#   已提取 4800/48187
#   已提取 6400/48187
#   已提取 8000/48187
#   已提取 9600/48187
#   已提取 11200/48187
#   已提取 12800/48187
#   已提取 14400/48187
#   已提取 16000/48187
#   已提取 17600/48187
#   已提取 19200/48187
#   已提取 20800/48187
#   已提取 22400/48187
#   已提取 24000/48187
#   已提取 25600/48187
#   已提取 27200/48187
#   已提取 28800/48187
#   已提取 30400/48187
#   已提取 32000/48187
#   已提取 33600/48187
#   已提取 35200/48187
#   已提取 36800/48187
#   已提取 38400/48187
#   已提取 40000/48187
#   已提取 41600/48187
#   已提取 43200/48187
#   已提取 44800/48187
#   已提取 46400/48187
#   已提取 48000/48187
#   已提取 48187/48187
# 特征缓存元信息: {'whisper_size': 'small', 'num_samples': 48187, 'enc_dim': 768, 'feature_dtype': 'float16'}
# 训练: 38549, 验证: 4818, 测试: 4820, batch_size: 256, feature_batch_size: 64, feature_num_workers: 8, feature_prefetch_factor: 2

# %% [markdown]
# ## 2. 构建模型

# %%
from models.whisper_emotion import WHISPER_DIMS

# 兼容：无论是否复用缓存/是否重启 kernel，都从配置中读取 whisper_size
whisper_size = cfg["model"]["whisper_size"]

enc_dim = WHISPER_DIMS[whisper_size]
num_classes = cfg["emotion"]["num_classes"]

classifier = nn.Sequential(
    nn.Linear(enc_dim, 256),
    nn.ReLU(inplace=True),
    nn.Dropout(0.3),
    nn.Linear(256, 64),
    nn.ReLU(inplace=True),
    nn.Dropout(0.2),
    nn.Linear(64, num_classes),
).to(device)

trainable = sum(p.numel() for p in classifier.parameters())
print(f"分类器可训练参数: {trainable:,}")
# Out:
# 分类器可训练参数: 213,702

# %% [markdown]
# ## 3. 训练

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(
    classifier.parameters(),
    lr=cfg['training']['learning_rate'],
    weight_decay=cfg['training']['weight_decay'],
)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', patience=5, factor=0.5,
)

epochs = cfg['training']['epochs']
patience = cfg['training']['patience']
best_val_loss = float('inf')
best_cls_state = None
wait = 0
history = {'train_loss': [], 'train_acc': [], 'val_loss': [], 'val_acc': []}

for epoch in range(1, epochs + 1):
    t0 = time.time()

    classifier.train()
    tr_loss, tr_correct, tr_total = 0, 0, 0
    for feats, labels in train_loader:
        feats, labels = feats.to(device), labels.to(device)
        optimizer.zero_grad()
        logits = classifier(feats)
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        tr_loss += loss.item() * feats.size(0)
        tr_correct += (logits.argmax(1) == labels).sum().item()
        tr_total += feats.size(0)

    classifier.eval()
    vl_loss, vl_correct, vl_total = 0, 0, 0
    with torch.no_grad():
        for feats, labels in val_loader:
            feats, labels = feats.to(device), labels.to(device)
            logits = classifier(feats)
            loss = criterion(logits, labels)
            vl_loss += loss.item() * feats.size(0)
            vl_correct += (logits.argmax(1) == labels).sum().item()
            vl_total += feats.size(0)

    tr_loss /= tr_total; tr_acc = tr_correct / tr_total
    vl_loss /= vl_total; vl_acc = vl_correct / vl_total
    scheduler.step(vl_loss)
    elapsed = time.time() - t0

    history['train_loss'].append(tr_loss)
    history['train_acc'].append(tr_acc)
    history['val_loss'].append(vl_loss)
    history['val_acc'].append(vl_acc)

    print(f'Epoch {epoch:3d}/{epochs} | '
          f'Train Loss: {tr_loss:.4f} Acc: {tr_acc:.4f} | '
          f'Val Loss: {vl_loss:.4f} Acc: {vl_acc:.4f} | {elapsed:.1f}s')

    if vl_loss < best_val_loss:
        best_val_loss = vl_loss
        best_cls_state = copy.deepcopy(classifier.state_dict())
        wait = 0
        print(f'  -> 最佳模型已保存')
    else:
        wait += 1
        if wait >= patience:
            print(f'\n早停: 连续 {patience} 轮无改善')
            break

os.makedirs(cfg['paths']['checkpoints'], exist_ok=True)
torch.save({
    'classifier_state': best_cls_state,
    'whisper_size': whisper_size,
    'num_classes': cfg['emotion']['num_classes'],
}, cfg['paths']['best_shared_model'])
np.savez(os.path.join(cfg['paths']['checkpoints'], 'shared_history.npz'), **history)
print(f'模型已保存至: {cfg["paths"]["best_shared_model"]}')
# Out:
# Epoch   1/100 | Train Loss: 1.4480 Acc: 0.3895 | Val Loss: 1.1398 Acc: 0.5612 | 4.0s
#   -> 最佳模型已保存
# Epoch   2/100 | Train Loss: 1.0538 Acc: 0.5940 | Val Loss: 0.8793 Acc: 0.6733 | 4.5s
#   -> 最佳模型已保存
# Epoch   3/100 | Train Loss: 0.8757 Acc: 0.6691 | Val Loss: 0.7452 Acc: 0.7202 | 4.6s
#   -> 最佳模型已保存
# Epoch   4/100 | Train Loss: 0.7812 Acc: 0.7013 | Val Loss: 0.6891 Acc: 0.7377 | 4.3s
#   -> 最佳模型已保存
# Epoch   5/100 | Train Loss: 0.7277 Acc: 0.7199 | Val Loss: 0.6379 Acc: 0.7551 | 4.6s
#   -> 最佳模型已保存
# Epoch   6/100 | Train Loss: 0.6786 Acc: 0.7419 | Val Loss: 0.6027 Acc: 0.7667 | 4.4s
#   -> 最佳模型已保存
# Epoch   7/100 | Train Loss: 0.6437 Acc: 0.7529 | Val Loss: 0.5703 Acc: 0.7758 | 4.2s
#   -> 最佳模型已保存
# Epoch   8/100 | Train Loss: 0.6198 Acc: 0.7612 | Val Loss: 0.5528 Acc: 0.7879 | 4.2s
#   -> 最佳模型已保存
# Epoch   9/100 | Train Loss: 0.5965 Acc: 0.7692 | Val Loss: 0.5378 Acc: 0.7947 | 4.2s
#   -> 最佳模型已保存
# Epoch  10/100 | Train Loss: 0.5792 Acc: 0.7774 | Val Loss: 0.5254 Acc: 0.7985 | 4.4s
#   -> 最佳模型已保存
# Epoch  11/100 | Train Loss: 0.5621 Acc: 0.7842 | Val Loss: 0.5195 Acc: 0.7976 | 4.4s
#   -> 最佳模型已保存
# Epoch  12/100 | Train Loss: 0.5516 Acc: 0.7866 | Val Loss: 0.4922 Acc: 0.8047 | 4.5s
#   -> 最佳模型已保存
# Epoch  13/100 | Train Loss: 0.5394 Acc: 0.7928 | Val Loss: 0.4974 Acc: 0.8055 | 4.6s
# Epoch  14/100 | Train Loss: 0.5246 Acc: 0.7983 | Val Loss: 0.4859 Acc: 0.8093 | 4.3s
#   -> 最佳模型已保存
# Epoch  15/100 | Train Loss: 0.5237 Acc: 0.7978 | Val Loss: 0.5184 Acc: 0.7962 | 4.4s
# Epoch  16/100 | Train Loss: 0.5121 Acc: 0.8021 | Val Loss: 0.4621 Acc: 0.8215 | 4.2s
#   -> 最佳模型已保存
# Epoch  17/100 | Train Loss: 0.5018 Acc: 0.8072 | Val Loss: 0.4641 Acc: 0.8215 | 4.6s
# Epoch  18/100 | Train Loss: 0.4976 Acc: 0.8089 | Val Loss: 0.4654 Acc: 0.8134 | 4.5s
# Epoch  19/100 | Train Loss: 0.4885 Acc: 0.8101 | Val Loss: 0.4473 Acc: 0.8300 | 4.8s
#   -> 最佳模型已保存
# Epoch  20/100 | Train Loss: 0.4834 Acc: 0.8141 | Val Loss: 0.4430 Acc: 0.8298 | 4.1s
#   -> 最佳模型已保存
# Epoch  21/100 | Train Loss: 0.4752 Acc: 0.8154 | Val Loss: 0.4621 Acc: 0.8215 | 3.8s
# Epoch  22/100 | Train Loss: 0.4732 Acc: 0.8180 | Val Loss: 0.4385 Acc: 0.8298 | 3.9s
#   -> 最佳模型已保存
# Epoch  23/100 | Train Loss: 0.4655 Acc: 0.8210 | Val Loss: 0.4325 Acc: 0.8315 | 4.4s
#   -> 最佳模型已保存
# Epoch  24/100 | Train Loss: 0.4557 Acc: 0.8235 | Val Loss: 0.4319 Acc: 0.8364 | 4.6s
#   -> 最佳模型已保存
# Epoch  25/100 | Train Loss: 0.4580 Acc: 0.8235 | Val Loss: 0.4518 Acc: 0.8252 | 4.0s
# Epoch  26/100 | Train Loss: 0.4544 Acc: 0.8268 | Val Loss: 0.4303 Acc: 0.8337 | 4.2s
#   -> 最佳模型已保存
# Epoch  27/100 | Train Loss: 0.4454 Acc: 0.8278 | Val Loss: 0.4371 Acc: 0.8333 | 3.9s
# Epoch  28/100 | Train Loss: 0.4384 Acc: 0.8311 | Val Loss: 0.4152 Acc: 0.8416 | 4.3s
#   -> 最佳模型已保存
# Epoch  29/100 | Train Loss: 0.4401 Acc: 0.8296 | Val Loss: 0.4239 Acc: 0.8315 | 4.2s
# Epoch  30/100 | Train Loss: 0.4398 Acc: 0.8301 | Val Loss: 0.4130 Acc: 0.8423 | 4.3s
#   -> 最佳模型已保存
# Epoch  31/100 | Train Loss: 0.4323 Acc: 0.8317 | Val Loss: 0.4032 Acc: 0.8435 | 4.4s
#   -> 最佳模型已保存
# Epoch  32/100 | Train Loss: 0.4281 Acc: 0.8326 | Val Loss: 0.4021 Acc: 0.8418 | 4.2s
#   -> 最佳模型已保存
# Epoch  33/100 | Train Loss: 0.4274 Acc: 0.8348 | Val Loss: 0.4093 Acc: 0.8414 | 4.4s
# Epoch  34/100 | Train Loss: 0.4233 Acc: 0.8388 | Val Loss: 0.4021 Acc: 0.8479 | 4.4s
#   -> 最佳模型已保存
# Epoch  35/100 | Train Loss: 0.4262 Acc: 0.8357 | Val Loss: 0.4132 Acc: 0.8425 | 4.1s
# Epoch  36/100 | Train Loss: 0.4242 Acc: 0.8353 | Val Loss: 0.4070 Acc: 0.8493 | 4.1s
# Epoch  37/100 | Train Loss: 0.4152 Acc: 0.8416 | Val Loss: 0.4079 Acc: 0.8456 | 4.3s
# Epoch  38/100 | Train Loss: 0.4161 Acc: 0.8390 | Val Loss: 0.3879 Acc: 0.8516 | 4.6s
#   -> 最佳模型已保存
# Epoch  39/100 | Train Loss: 0.4064 Acc: 0.8441 | Val Loss: 0.3923 Acc: 0.8506 | 4.3s
# Epoch  40/100 | Train Loss: 0.4123 Acc: 0.8400 | Val Loss: 0.3977 Acc: 0.8470 | 4.3s
# Epoch  41/100 | Train Loss: 0.4091 Acc: 0.8439 | Val Loss: 0.4031 Acc: 0.8489 | 4.6s
# Epoch  42/100 | Train Loss: 0.4137 Acc: 0.8405 | Val Loss: 0.3909 Acc: 0.8512 | 4.5s
# Epoch  43/100 | Train Loss: 0.4020 Acc: 0.8443 | Val Loss: 0.3849 Acc: 0.8557 | 4.4s
#   -> 最佳模型已保存
# Epoch  44/100 | Train Loss: 0.4047 Acc: 0.8454 | Val Loss: 0.4126 Acc: 0.8373 | 4.6s
# Epoch  45/100 | Train Loss: 0.3971 Acc: 0.8484 | Val Loss: 0.3982 Acc: 0.8439 | 4.5s
# Epoch  46/100 | Train Loss: 0.3979 Acc: 0.8485 | Val Loss: 0.3841 Acc: 0.8599 | 4.4s
#   -> 最佳模型已保存
# Epoch  47/100 | Train Loss: 0.3892 Acc: 0.8495 | Val Loss: 0.3881 Acc: 0.8539 | 4.4s
# Epoch  48/100 | Train Loss: 0.3942 Acc: 0.8495 | Val Loss: 0.4059 Acc: 0.8412 | 4.6s
# Epoch  49/100 | Train Loss: 0.3890 Acc: 0.8511 | Val Loss: 0.3664 Acc: 0.8624 | 4.9s
#   -> 最佳模型已保存
# Epoch  50/100 | Train Loss: 0.3914 Acc: 0.8488 | Val Loss: 0.3734 Acc: 0.8584 | 4.1s
# Epoch  51/100 | Train Loss: 0.3889 Acc: 0.8501 | Val Loss: 0.3864 Acc: 0.8524 | 4.6s
# Epoch  52/100 | Train Loss: 0.3855 Acc: 0.8504 | Val Loss: 0.3720 Acc: 0.8618 | 4.4s
# Epoch  53/100 | Train Loss: 0.3830 Acc: 0.8525 | Val Loss: 0.3712 Acc: 0.8589 | 4.3s
# Epoch  54/100 | Train Loss: 0.3875 Acc: 0.8517 | Val Loss: 0.3880 Acc: 0.8487 | 4.2s
# Epoch  55/100 | Train Loss: 0.3853 Acc: 0.8515 | Val Loss: 0.3781 Acc: 0.8607 | 4.7s
# Epoch  56/100 | Train Loss: 0.3569 Acc: 0.8630 | Val Loss: 0.3530 Acc: 0.8703 | 4.3s
#   -> 最佳模型已保存
# Epoch  57/100 | Train Loss: 0.3552 Acc: 0.8634 | Val Loss: 0.3538 Acc: 0.8649 | 4.1s
# Epoch  58/100 | Train Loss: 0.3515 Acc: 0.8648 | Val Loss: 0.3578 Acc: 0.8630 | 4.3s
# Epoch  59/100 | Train Loss: 0.3496 Acc: 0.8671 | Val Loss: 0.3484 Acc: 0.8688 | 4.2s
#   -> 最佳模型已保存
# Epoch  60/100 | Train Loss: 0.3436 Acc: 0.8676 | Val Loss: 0.3497 Acc: 0.8670 | 4.3s
# Epoch  61/100 | Train Loss: 0.3448 Acc: 0.8679 | Val Loss: 0.3674 Acc: 0.8599 | 4.4s
# Epoch  62/100 | Train Loss: 0.3409 Acc: 0.8683 | Val Loss: 0.3592 Acc: 0.8641 | 4.7s
# Epoch  63/100 | Train Loss: 0.3406 Acc: 0.8698 | Val Loss: 0.3524 Acc: 0.8659 | 4.3s
# Epoch  64/100 | Train Loss: 0.3413 Acc: 0.8701 | Val Loss: 0.3459 Acc: 0.8715 | 4.2s
#   -> 最佳模型已保存
# Epoch  65/100 | Train Loss: 0.3389 Acc: 0.8695 | Val Loss: 0.3542 Acc: 0.8651 | 4.5s
# Epoch  66/100 | Train Loss: 0.3358 Acc: 0.8704 | Val Loss: 0.3547 Acc: 0.8680 | 4.2s
# Epoch  67/100 | Train Loss: 0.3310 Acc: 0.8721 | Val Loss: 0.3475 Acc: 0.8688 | 4.2s
# Epoch  68/100 | Train Loss: 0.3362 Acc: 0.8721 | Val Loss: 0.3495 Acc: 0.8676 | 4.5s
# Epoch  69/100 | Train Loss: 0.3350 Acc: 0.8717 | Val Loss: 0.3559 Acc: 0.8645 | 4.6s
# Epoch  70/100 | Train Loss: 0.3355 Acc: 0.8711 | Val Loss: 0.3593 Acc: 0.8651 | 4.4s
# Epoch  71/100 | Train Loss: 0.3142 Acc: 0.8804 | Val Loss: 0.3425 Acc: 0.8686 | 4.5s
#   -> 最佳模型已保存
# Epoch  72/100 | Train Loss: 0.3142 Acc: 0.8796 | Val Loss: 0.3456 Acc: 0.8676 | 4.3s
# Epoch  73/100 | Train Loss: 0.3162 Acc: 0.8797 | Val Loss: 0.3419 Acc: 0.8701 | 4.4s
#   -> 最佳模型已保存
# Epoch  74/100 | Train Loss: 0.3143 Acc: 0.8794 | Val Loss: 0.3474 Acc: 0.8667 | 4.4s
# Epoch  75/100 | Train Loss: 0.3139 Acc: 0.8802 | Val Loss: 0.3399 Acc: 0.8707 | 4.5s
#   -> 最佳模型已保存
# Epoch  76/100 | Train Loss: 0.3111 Acc: 0.8810 | Val Loss: 0.3426 Acc: 0.8701 | 4.5s
# Epoch  77/100 | Train Loss: 0.3129 Acc: 0.8802 | Val Loss: 0.3428 Acc: 0.8680 | 4.3s
# Epoch  78/100 | Train Loss: 0.3119 Acc: 0.8819 | Val Loss: 0.3416 Acc: 0.8705 | 4.6s
# Epoch  79/100 | Train Loss: 0.3132 Acc: 0.8800 | Val Loss: 0.3455 Acc: 0.8707 | 4.4s
# Epoch  80/100 | Train Loss: 0.3116 Acc: 0.8811 | Val Loss: 0.3395 Acc: 0.8690 | 4.3s
#   -> 最佳模型已保存
# Epoch  81/100 | Train Loss: 0.3075 Acc: 0.8821 | Val Loss: 0.3481 Acc: 0.8676 | 4.4s
# Epoch  82/100 | Train Loss: 0.3057 Acc: 0.8831 | Val Loss: 0.3394 Acc: 0.8717 | 4.5s
#   -> 最佳模型已保存
# Epoch  83/100 | Train Loss: 0.3068 Acc: 0.8831 | Val Loss: 0.3421 Acc: 0.8705 | 5.0s
# Epoch  84/100 | Train Loss: 0.3088 Acc: 0.8831 | Val Loss: 0.3449 Acc: 0.8678 | 4.6s
# Epoch  85/100 | Train Loss: 0.3065 Acc: 0.8840 | Val Loss: 0.3378 Acc: 0.8705 | 4.7s
#   -> 最佳模型已保存
# Epoch  86/100 | Train Loss: 0.3065 Acc: 0.8825 | Val Loss: 0.3356 Acc: 0.8748 | 4.5s
#   -> 最佳模型已保存
# Epoch  87/100 | Train Loss: 0.3014 Acc: 0.8850 | Val Loss: 0.3389 Acc: 0.8724 | 4.5s
# Epoch  88/100 | Train Loss: 0.3039 Acc: 0.8837 | Val Loss: 0.3375 Acc: 0.8692 | 4.8s
# Epoch  89/100 | Train Loss: 0.3034 Acc: 0.8820 | Val Loss: 0.3421 Acc: 0.8692 | 4.3s
# Epoch  90/100 | Train Loss: 0.3004 Acc: 0.8864 | Val Loss: 0.3371 Acc: 0.8719 | 4.6s
# Epoch  91/100 | Train Loss: 0.2983 Acc: 0.8868 | Val Loss: 0.3380 Acc: 0.8721 | 4.8s
# Epoch  92/100 | Train Loss: 0.3000 Acc: 0.8850 | Val Loss: 0.3366 Acc: 0.8715 | 4.4s
# Epoch  93/100 | Train Loss: 0.2939 Acc: 0.8892 | Val Loss: 0.3346 Acc: 0.8686 | 5.1s
#   -> 最佳模型已保存
# Epoch  94/100 | Train Loss: 0.2929 Acc: 0.8886 | Val Loss: 0.3355 Acc: 0.8734 | 6.9s
# Epoch  95/100 | Train Loss: 0.2906 Acc: 0.8899 | Val Loss: 0.3356 Acc: 0.8715 | 5.3s
# Epoch  96/100 | Train Loss: 0.2931 Acc: 0.8891 | Val Loss: 0.3341 Acc: 0.8738 | 4.3s
#   -> 最佳模型已保存
# Epoch  97/100 | Train Loss: 0.2914 Acc: 0.8884 | Val Loss: 0.3342 Acc: 0.8738 | 4.4s
# Epoch  98/100 | Train Loss: 0.2922 Acc: 0.8884 | Val Loss: 0.3314 Acc: 0.8755 | 4.3s
#   -> 最佳模型已保存
# Epoch  99/100 | Train Loss: 0.2922 Acc: 0.8883 | Val Loss: 0.3361 Acc: 0.8703 | 4.4s
# Epoch 100/100 | Train Loss: 0.2895 Acc: 0.8893 | Val Loss: 0.3332 Acc: 0.8734 | 4.8s
# 模型已保存至: checkpoints/best_shared.pth

# %% [markdown]
# ## 4. 训练曲线

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
ax1.plot(history['train_loss'], label='Train')
ax1.plot(history['val_loss'], label='Validation')
ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss')
ax1.set_title('Loss - Whisper Shared Encoder')
ax1.legend(); ax1.grid(True, alpha=0.3)

ax2.plot(history['train_acc'], label='Train')
ax2.plot(history['val_acc'], label='Validation')
ax2.set_xlabel('Epoch'); ax2.set_ylabel('Accuracy')
ax2.set_title('Accuracy - Whisper Shared Encoder')
ax2.legend(); ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(cfg['paths']['checkpoints'], 'shared_training_curves.png'), dpi=150)
plt.show()

# %% [markdown]
# ## 5. 测试集评估

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

classifier.load_state_dict(best_cls_state)
classifier.eval()

all_preds, all_labels_list = [], []
with torch.no_grad():
    for feats, labels in test_loader:
        feats = feats.to(device)
        preds = classifier(feats).argmax(1).cpu().numpy()
        all_preds.extend(preds)
        all_labels_list.extend(labels.numpy())

print(classification_report(all_labels_list, all_preds, target_names=EMOTION_LABELS, zero_division=0))

cm = confusion_matrix(all_labels_list, all_preds)
fig, ax = plt.subplots(figsize=(8, 6))
ConfusionMatrixDisplay(cm, display_labels=EMOTION_LABELS).plot(ax=ax, cmap='Blues', values_format='d')
ax.set_title('Confusion Matrix - Whisper Shared Encoder')
plt.tight_layout()
plt.savefig(os.path.join(cfg['paths']['checkpoints'], 'shared_confusion_matrix.png'), dpi=150)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        happy       0.85      0.81      0.83       928
#        angry       0.87      0.89      0.88      1069
#          sad       0.90      0.89      0.89       889
#      neutral       0.83      0.88      0.86       967
#         fear       0.83      0.70      0.76       125
#     surprise       0.91      0.89      0.90       842
#
#     accuracy                           0.87      4820
#    macro avg       0.86      0.84      0.85      4820
# weighted avg       0.87      0.87      0.87      4820

# %% [markdown]
# ## 6. 对比两个模型
# 如果之前已经训练过 CNN+BiLSTM+Attention 模型，可以加载对比。

# %%
emotion_hist_path = os.path.join(cfg['paths']['checkpoints'], 'emotion_history.npz')
shared_hist_path = os.path.join(cfg['paths']['checkpoints'], 'shared_history.npz')

if os.path.isfile(emotion_hist_path) and os.path.isfile(shared_hist_path):
    eh = np.load(emotion_hist_path)
    sh = np.load(shared_hist_path)
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
    ax1.plot(eh['val_loss'], label='CNN+BiLSTM+Attn', color='blue')
    ax1.plot(sh['val_loss'], label='Whisper Shared', color='red')
    ax1.set_xlabel('Epoch'); ax1.set_ylabel('Val Loss')
    ax1.set_title('Comparison of validation set loss')
    ax1.legend(); ax1.grid(True, alpha=0.3)
    
    ax2.plot(eh['val_acc'], label='CNN+BiLSTM+Attn', color='blue')
    ax2.plot(sh['val_acc'], label='Whisper Shared', color='red')
    ax2.set_xlabel('Epoch'); ax2.set_ylabel('Val Accuracy')
    ax2.set_title('Comparison of validation set accuracy')
    ax2.legend(); ax2.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(cfg['paths']['checkpoints'], 'model_comparison.png'), dpi=150)
    plt.show()
else:
    print('缺少其中一个模型的训练历史，跳过对比。')
